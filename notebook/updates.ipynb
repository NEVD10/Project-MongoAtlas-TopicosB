# %% [markdown]
# # Update

# %%
from connect import db
from pymongo import UpdateOne

libros  = db.libros
# Out:
# Conexion exitosa a Atlas
# Conectado Mongo DB Atlas: Base de Datos Biblioteca2026
# Colecciones:  ['libros']

# %%
# UpdateOne
#Actualizar el stock de un libro
res = libros.update_one({'titulo' : "La casa verde"}, 
                        {'$inc' : {'stock': 5}})
print(res.matched_count, res.modified_count)
# Out:
# 1 1
